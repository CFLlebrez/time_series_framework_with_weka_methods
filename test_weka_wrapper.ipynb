# %% [markdown]
# Primero limpiaré el csv para realizar la predicción.

# %%
import pandas as pd

osuna = pd.read_csv("results/osuna_clean_output/transformed_data_fv9_fh20_ph1.csv")

print(osuna.head())
# Out:
#         FECHA  DIA_t-1  Se11TMax_t-1  Se11TMin_t-1  Se11TMed_t-1  \
# 0  2025-12-14    348.0          19.1           5.9          11.5
# 1  2025-12-13    347.0          19.3           8.8          13.2
# 2  2025-12-12    346.0          15.5           7.7          12.7
# 3  2025-12-11    345.0          17.4           5.9          11.8
# 4  2025-12-10    344.0          12.6           9.9          11.3
#
#    Se11HumMax_t-1  Se11HumMin_t-1  Se11HumMed_t-1  Se11VelViento_t-1  \
# 0           100.0            46.2            82.4                0.7
# 1           100.0            48.2            76.2                0.9
# 2           100.0            68.6            81.0                1.2
# 3            99.8            54.1            83.0                0.4
# 4           100.0            60.3            92.7                0.4
#
#    Se11VelVientoMax_t-1  ...  Se11VelVientoMax_t+11  Se11VelVientoMax_t+12  \
# 0                   3.8  ...                    5.0                    5.1
# 1                   4.3  ...                    5.1                    2.8
# 2                   5.0  ...                    2.8                    4.9
# 3                   3.5  ...                    4.9                    4.0
# 4                   2.8  ...                    4.0                    2.5
#
#    Se11VelVientoMax_t+13  Se11VelVientoMax_t+14  Se11VelVientoMax_t+15  \
# 0                    2.8                    4.9                    4.0
# 1                    4.9                    4.0                    2.5
# 2                    4.0                    2.5                    4.9
# 3                    2.5                    4.9                    5.0
# 4                    4.9                    5.0                    5.4
#
#    Se11VelVientoMax_t+16  Se11VelVientoMax_t+17  Se11VelVientoMax_t+18  \
# 0                    2.5                    4.9                    5.0
# 1                    4.9                    5.0                    5.4
# 2                    5.0                    5.4                    5.7
# 3                    5.4                    5.7                    3.7
# 4                    5.7                    3.7                    4.7
#
#    Se11VelVientoMax_t+19  Se11VelVientoMax_t+20
# 0                    5.4                    5.7
# 1                    5.7                    3.7
# 2                    3.7                    4.7
# 3                    4.7                    5.5
# 4                    5.5                    3.6
#
# [5 rows x 34 columns]

# %%
print(osuna.columns)
# Out:
# Index(['FECHA', 'DIA_t-1', 'Se11TMax_t-1', 'Se11TMin_t-1', 'Se11TMed_t-1',
#        'Se11HumMax_t-1', 'Se11HumMin_t-1', 'Se11HumMed_t-1',
#        'Se11VelViento_t-1', 'Se11VelVientoMax_t-1', 'Se11DirViento_t-1',
#        'Se11Rad_t-1', 'Se11Precip_t-1', 'Se11VelVientoMax',
#        'Se11VelVientoMax_t+1', 'Se11VelVientoMax_t+2', 'Se11VelVientoMax_t+3',
#        'Se11VelVientoMax_t+4', 'Se11VelVientoMax_t+5', 'Se11VelVientoMax_t+6',
#        'Se11VelVientoMax_t+7', 'Se11VelVientoMax_t+8', 'Se11VelVientoMax_t+9',
#        'Se11VelVientoMax_t+10', 'Se11VelVientoMax_t+11',
#        'Se11VelVientoMax_t+12', 'Se11VelVientoMax_t+13',
#        'Se11VelVientoMax_t+14', 'Se11VelVientoMax_t+15',
#        'Se11VelVientoMax_t+16', 'Se11VelVientoMax_t+17',
#        'Se11VelVientoMax_t+18', 'Se11VelVientoMax_t+19',
#        'Se11VelVientoMax_t+20'],
#       dtype='object')

# %%
osuna = osuna.drop(labels=['FECHA', 'DIA_t-1', 'Se11VelVientoMax_t+1', 'Se11VelVientoMax_t+2', 'Se11VelVientoMax_t+3',
       'Se11VelVientoMax_t+4', 'Se11VelVientoMax_t+5', 'Se11VelVientoMax_t+6',
       'Se11VelVientoMax_t+7', 'Se11VelVientoMax_t+8', 'Se11VelVientoMax_t+9',
       'Se11VelVientoMax_t+10', 'Se11VelVientoMax_t+11',
       'Se11VelVientoMax_t+12', 'Se11VelVientoMax_t+13',
       'Se11VelVientoMax_t+14', 'Se11VelVientoMax_t+15',
       'Se11VelVientoMax_t+16', 'Se11VelVientoMax_t+17',
       'Se11VelVientoMax_t+18', 'Se11VelVientoMax_t+19',
       'Se11VelVientoMax_t+20'], axis=1)

# %%
osuna.loc[:, ~osuna.columns.str.contains('^Unnamed')]
osuna.dropna(inplace=True)

# %%
osuna.to_csv('test_weka_wrapper.csv')

# %%
import weka.core.jvm as jvm
jvm.start()
# Out:
# INFO:weka.core.jvm:JVM already running, call jvm.stop() first

# %%
import weka.core.converters as converters

data_dir = "test_weka_wrapper.csv"

data = converters.load_any_file(data_dir)
data.class_is_last()

print(data)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File CSVLoader.java:877, in weka.core.converters.CSVLoader.getDataSet()
#
# Exception: Java Exception
#
# The above exception was the direct cause of the following exception:
#
# java.io.IOException                       Traceback (most recent call last)
# Cell In[25], line 5
#       1 import weka.core.converters as converters
#       3 data_dir = "test_weka_wrapper.csv"
# ----> 5 data = converters.load_any_file(data_dir)
#       6 data.class_is_last()
#       8 print(data)
#
# File c:\Users\pacos\AppData\Local\Programs\Python\Python312\Lib\site-packages\weka\core\converters.py:276, in load_any_file(filename, class_index)
#     274     return None
#     275 else:
# --> 276     return loader.load_file(filename, class_index=class_index)
#
# File c:\Users\pacos\AppData\Local\Programs\Python\Python312\Lib\site-packages\weka\core\converters.py:91, in Loader.load_file(self, dfile, incremental, class_index)
#      89     result = self.structure
#      90 else:
# ---> 91     result = Instances(self.jobject.getDataSet())
#      92 if class_index is not None:
#      93     if class_index == 'first':
#
# java.io.IOException: java.io.IOException: Index 32 out of bounds for length 32 Problem encountered on line: 2

# %%
from weka.attribute_selection import ASSearch, ASEvaluation, AttributeSelection
search = ASSearch(classname="weka.attributeSelection.BestFirst", options=["-D", "1", "-N", "5"])
evaluator = ASEvaluation(classname="weka.attributeSelection.CfsSubsetEval", options=["-P", "1", "-E", "1"])
attsel = AttributeSelection()
attsel.search(search)
attsel.evaluator(evaluator)
attsel.select_attributes(data)

print("# attributes: " + str(attsel.number_attributes_selected))
print("attributes: " + str(attsel.selected_attributes))
print("result string:\n" + attsel.results_string)
# Out:
# # attributes: 5
# attributes: [ 0.  1. 10. 26. 32. 33.]
# result string:
#
#
# === Attribute Selection on all input data ===
#
# Search Method:
# 	Best first.
# 	Start set: no attributes
# 	Search direction: forward
# 	Stale search after 5 node expansions
# 	Total number of subsets evaluated: 216
# 	Merit of best subset found:    0.477
#
# Attribute Subset Evaluator (supervised, Class (numeric): 34 Se11VelVientoMax_t+20):
# 	CFS Subset Evaluator
# 	Including locally predictive attributes
#
# Selected attributes: 1,2,11,27,33 : 5
#                      FECHA
#                      DIA_t-1
#                      Se11DirViento_t-1
#                      Se11VelVientoMax_t+13
#                      Se11VelVientoMax_t+19
